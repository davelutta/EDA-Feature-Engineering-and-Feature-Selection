# %%
import pandas as pd
students= {"name":["Braund, Mr. Owen Harris","Allen, Mr. William Henry","Bonnel, Miss. ELizabeth"],
          "Marks":[22,35,58],
          "sex":["male","male","female"]}
df=pd.DataFrame(data=students)
df
# Out:
#                        name  Marks     sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2   Bonnel, Miss. ELizabeth     58  female

# %%
df["Marks"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Marks, dtype: int64

# %%
marks=pd.Series([22,35,58], name="Age")
marks
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
df
# Out:
#                        name  Marks     sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2   Bonnel, Miss. ELizabeth     58  female

# %%
df.head(2)
# Out:
#                        name  Marks   sex
# 0   Braund, Mr. Owen Harris     22  male
# 1  Allen, Mr. William Henry     35  male

# %%
df.tail(2)
# Out:
#                        name  Marks     sex
# 1  Allen, Mr. William Henry     35    male
# 2   Bonnel, Miss. ELizabeth     58  female

# %%
df["Marks"].max()
# Out:
# 58

# %%
df.Marks.max()
# Out:
# 58

# %%
df.describe()
# Out:
#            Marks
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   Marks   3 non-null      int64
#  2   sex     3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
telcom=pd.read_csv('D:\python\JULY_COHORT-master\lesson1_Telco_churn\Telco-Customer-Churn.csv')

# %%
telcom
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
telcom.to_excel('telcom.xlsx',sheet_name='customers',index=False)

# %%
telcom_excel=pd.read_excel('telcom.xlsx',sheet_name='customers')
telcom_excel.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %%
telcom_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('sqlite:///:memory:')

# %%
data={'A':['foo','foo','bar','bar','bar'],
    'B':['one','one','two','one','one'],
    'C':['x','y','y','x','y'],
    'D':[1,2,3,5,4]}
df=pd.DataFrame(data)
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  2
# 2  bar  two  y  3
# 3  bar  one  x  5
# 4  bar  one  y  4

# %%
df.to_sql('my_comps',engine)
# Out:
# 5

# %%
sql_df=pd.read_sql('my_comps',con=engine)

# %%
sql_df
# Out:
#    index    A    B  C  D
# 0      0  foo  one  x  1
# 1      1  foo  one  y  2
# 2      2  bar  two  y  3
# 3      3  bar  one  x  5
# 4      4  bar  one  y  4

# %%
pd.read_html('https://en.wikipedia.org/wiki/Counties_of_Kenya')[2]
# Out:
#     Code           County Former Province  Area (km2)  \
# 0    1.0          Mombasa           Coast       212.5
# 1    2.0            Kwale           Coast      8270.3
# 2    3.0           Kilifi           Coast     12245.9
# 3    4.0       Tana River           Coast     35375.8
# 4    5.0             Lamu           Coast      6497.7
# 5    6.0     Taita–Taveta           Coast     17083.9
# 6    7.0          Garissa   North Eastern     45720.2
# 7    8.0            Wajir   North Eastern     55840.6
# 8    9.0          Mandera   North Eastern     25797.7
# 9   10.0         Marsabit         Eastern     66923.1
# 10  11.0           Isiolo         Eastern     25336.1
# 11  12.0             Meru         Eastern      7003.1
# 12  13.0    Tharaka-Nithi         Eastern      2609.5
# 13  14.0             Embu         Eastern      2555.9
# 14  15.0            Kitui         Eastern     24385.1
# 15  16.0         Machakos         Eastern      5952.9
# ...

# %%
telcom_excel.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
#
# [1 rows x 21 columns]

# %%
telcom.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
MonthlyCharges=telcom['MonthlyCharges']

# %%
MonthlyCharges.head(20)
# Out:
# 0      29.85
# 1      56.95
# 2      53.85
# 3      42.30
# 4      70.70
# 5      99.65
# 6      89.10
# 7      29.75
# 8     104.80
# 9      56.15
# 10     49.95
# 11     18.95
# 12    100.35
# 13    103.70
# 14    105.50
# 15    113.25
# 16     20.65
# 17    106.70
# 18     55.20
# 19     90.05
# Name: MonthlyCharges, dtype: float64

# %%
type(telcom['MonthlyCharges'])
# Out:
# pandas.core.series.Series

# %%
telcom['MonthlyCharges'].shape
# Out:
# (7043,)

# %%
revenue=telcom[['MonthlyCharges','TotalCharges','Churn']]
revenue.head()
# Out:
#    MonthlyCharges TotalCharges Churn
# 0           29.85        29.85    No
# 1           56.95       1889.5    No
# 2           53.85       108.15   Yes
# 3           42.30      1840.75    No
# 4           70.70       151.65   Yes

# %%
paid_above_100= telcom['MonthlyCharges']>100

# %%
paid_above_100.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
# 14            No     Fiber optic            Yes  ...              Yes
# 15           Yes     Fiber optic            Yes  ...              Yes
#
# ...

# %%
paid_above_100.count()
# Out:
# 7043

# %%
 contract_month_and_1year=telcom[telcom['Contract'].isin(['Month_to_month','One year'])]
print(contract_month_and_1year.head())
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 16  8191-XWSZG  Female              0      No         No      52          Yes
#
#        MultipleLines InternetService       OnlineSecurity  ...  \
# 1                 No             DSL                  Yes  ...
# 3   No phone service             DSL                  Yes  ...
# 9                 No             DSL                  Yes  ...
# 12               Yes     Fiber optic                   No  ...
# 16                No              No  No internet service  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
status_no_na=telcom[telcom['Partner'].notna()]
status_no_na.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telcom.iloc[0:3,3] ="6"
telcom.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents tenure PhoneService  \
# 0  7590-VHVEG  Female              0       6         No      1           No
# 1  5575-GNVDE    Male              0       6         No     34          Yes
# 2  3668-QPYBK    Male              0       6         No      2          Yes
# 3  7795-CFOCW    Male              0      No         No     45           No
# 4  9237-HQITU  Female              0      No         No      2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telcom.loc[[10,1,5,700,60,50],['MonthlyCharges','TotalCharges','Churn']]
# Out:
#      MonthlyCharges TotalCharges Churn
# 10            49.95       587.45    No
# 1             56.95       1889.5    No
# 5             99.65        820.5   Yes
# 700           63.30       4189.7    No
# 60           100.50       4707.1    No
# 50            90.25      3838.75    No

# %%
telcom.iloc[[10,1,5,700,60,50],[-3,-2,-1]]
# Out:
#      MonthlyCharges TotalCharges Churn
# 10            49.95       587.45    No
# 1             56.95       1889.5    No
# 5             99.65        820.5   Yes
# 700           63.30       4189.7    No
# 60           100.50       4707.1    No
# 50            90.25      3838.75    No

# %%
 telcom.plot(x='SeniorCitizen', y='tenure')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 telcom.plot(x='SeniorCitizen', y='tenure')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:451, in MPLPlot.generate(self)
#     449 def generate(self) -> None:
# ...

# %%
telcom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   object
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
 telcom.plot(x='SeniorCitizen', y='tenure', kind='scatter')
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='tenure'>

# %%
telcom['MonthlyCharges'].plot.box()
# Out:
# <Axes: >

# %%
telcom.tenure.plot.box()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 telcom.tenure.plot.box()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1348, in PlotAccessor.box(self, by, **kwargs)
#    1283 def box(self, by: IndexLabel | None = None, **kwargs) -> PlotAccessor:
#    1284     r"""
#    1285     Make a box plot of the DataFrame columns.
#    1286
#    (...)
#    1346         >>> ax = df.plot.box(column="age", by="gender", figsize=(10, 8))
#    1347     """
# -> 1348     return self(kind="box", by=by, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
telcom["ForecastMonthly"]=telcom["MonthlyCharges"]* 10
telcom.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents tenure PhoneService  \
# 0  7590-VHVEG  Female              0       6         No      1           No
# 1  5575-GNVDE    Male              0       6         No     34          Yes
# 2  3668-QPYBK    Male              0       6         No      2          Yes
# 3  7795-CFOCW    Male              0      No         No     45           No
# 4  9237-HQITU  Female              0      No         No      2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
telcom_renamed=telcom.rename(
    columns={'ForecastMonthly':'Forecast','Churn':'ChurnedCustomer'})
telcom_renamed.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents tenure PhoneService  \
# 0  7590-VHVEG  Female              0       6         No      1           No
# 1  5575-GNVDE    Male              0       6         No     34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
#
#       PaymentMethod MonthlyCharges TotalCharges  ChurnedCustomer Forecast
# 0  Electronic check          29.85        29.85               No    298.5
# 1      Mailed check          56.95       1889.5               No    569.5
#
# [2 rows x 22 columns]

# %%
df=pd.read_csv('C:\Users\HP\Downloads\titanic.csv')
# Out:
#   Cell In[109], line 1
#     df=pd.read_csv('C:\Users\HP\Downloads\titanic.csv')
#                                                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
titanic = pd.read_csv('C:/Users/HP/Downloads/titanic.csv')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic[['age','fare']].max()
# Out:
# age      80.0000
# fare    512.3292
# dtype: float64

# %%
titanic.age.mean()
# Out:
# 29.69911764705882

# %%
titanic[['age','fare']].describe()
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic.agg({'age':['min','max','median','skew'],
            'fare':['min','max','median','skew']})
# Out:
#               age        fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108    4.787317

# %%
titanic['male','female'].mean(age)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('male', 'female')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 titanic['male','female'].mean(age)
#
# ...

# %%
titanic[['sex','age']].groupby('sex').mean()
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby(['sex','pclass'])['fare'].mean()
# Out:
# sex     pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: fare, dtype: float64

# %%
titanic['pclass'].count()
# Out:
# 891

# %%
titanic.sort_values(by='age').head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False

# %%
titanic.sort_values(by=['pclass','age'],ascending=False).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 851         0       3    male  74.0      0      0  7.7750        S  Third
# 116         0       3    male  70.5      0      0  7.7500        Q  Third
# 280         0       3    male  65.0      0      0  7.7500        Q  Third
# 483         1       3  female  63.0      0      0  9.5875        S  Third
# 326         0       3    male  61.0      0      0  6.2375        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 851    man        True  NaN  Southampton    no   True
# 116    man        True  NaN   Queenstown    no   True
# 280    man        True  NaN   Queenstown    no   True
# 483  woman       False  NaN  Southampton   yes   True
# 326    man        True  NaN  Southampton    no   True

# %%
pf1=pd.DataFrame({'A':['A0','A1','A2','A3'],
                 'B':['B0','B1','B2','B3'],
                 'C':['C0','C1','C2','C3'],
                  'D':['D0','D1','D2','D3']},
                index=[0,1,2,3])

# %%
pf2=pd.DataFrame({'A':['A4','A5','A6','A7'],
                 'B':['B4','B5','B6','B7'],
                 'C':['C4','C5','C6','C7'],
                  'D':['D4','D5','D6','D7']},
                index=[4,5,6,7])

# %%
pf3=pd.DataFrame({'A':['A8','A9','A10','A11'],
                 'B':['B8','B9','B10','B11'],
                 'C':['C8','C9','C10','C11'],
                  'D':['D8','D9','D10','D11']},
                index=[8,9,10,11])

# %%
pf1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pf2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([pf1,pf2,pf3], axis=0)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
pf5=pd.DataFrame({'A':['A17','A1','A2','A3'],
                 'B':['B0','B1','B2','B3'],
                 'C':['C0','C1','C2','C3'],
                  'D':['D0','D1','D2','D3']},
                index=[0,1,2,3])

# %%
pf6=pd.DataFrame({'A':['A17','A1','A2','A3'],
                 'B':['B0','B1','B2','B3'],
                 'C':['C0','C1','C2','C3'],
                  'D':['D0','D1','D2','D3']},
                index=[0,1,2,3])

# %%
pd.merge(pf5,pf6,how='inner')
# Out:
#      A   B   C   D
# 0  A17  B0  C0  D0
# 1   A1  B1  C1  D1
# 2   A2  B2  C2  D2
# 3   A3  B3  C3  D3

# %%
pf5.join(pf6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 pf5.join(pf6)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10412, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10402     if how == "cross":
#   10403         return merge(
#   10404             self,
#   10405             other,
#    (...)
#   10410             validate=validate,
#   10411         )
# > 10412     return merge(
#   10413         self,
#   10414         other,
#   10415         left_on=on,
#   10416         how=how,
#   10417         left_index=on is None,
#   10418         right_index=True,
#   10419         suffixes=(lsuffix, rsuffix),
#   10420         sort=sort,
#   10421         validate=validate,
#   10422     )
#   10423 else:
#   10424     if on is not None:
#
# ...
